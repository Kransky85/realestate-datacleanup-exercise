# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
most_expensive_home_ID = ds['price'].argmax()

most_expensive_home_value = ds['price'].max()

print(f"The house with ID {most_expensive_home_ID} is the most expensive and its price is {most_expensive_home_value} USD")
# Out:
# The house with ID 13110 is the most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
most_expensive_home_ID = ds['price'].argmax()

most_expensive_home_value = ds['price'].max()

print(f"The house with ID {most_expensive_home_ID} is the most expensive and its price is {most_expensive_home_value} USD")
# Out:
# The house with ID 13110 is the most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
largest_house_ID = ds['surface'].argmax()
smallest_house_ID = ds['surface'].argmin()

largest_house = ds.iloc[largest_house_ID]
smallest_house = ds.iloc[smallest_house_ID]

print(f"The biggest house is located at {largest_house['address']} and its surface is {largest_house['surface']} meters")

print(f"The smallest house is located at {smallest_house['address']} and its surface is {smallest_house['surface']} meters")
# Out:
# The biggest house is located at Sevilla la Nueva and its surface is 249000.0 meters
# The smallest house is located at Calle Amparo,  Madrid Capital and its surface is 15.0 meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
population_list = ds['level5'].unique()
sorted_population_list = sorted(list(population_list))

print(sorted_population_list)


#column = ds['level5'].unique()
#population = [z for x in column for z in x.split(', ')]

#population
# Out:
# [' Madrid Capital', 'Ajalvir', 'Alcalá de Henares', 'Alcobendas', 'Alcorcón', 'Aldea del Fresno', 'Algete', 'Alpedrete', 'Ambite', 'Anchuelo', 'Aranjuez', 'Arganda del Rey', 'Arroyomolinos (Madrid)', 'Batres', 'Becerril de la Sierra', 'Belmonte de Tajo', 'Boadilla del Monte', 'Braojos', 'Brea de Tajo', 'Brunete', 'Buitrago del Lozoya', 'Bustarviejo', 'Cabanillas de la Sierra', 'Cadalso de los Vidrios', 'Camarma de Esteruelas', 'Campo Real', 'Canencia', 'Carabaña', 'Casarrubuelos', 'Cenicientos', 'Cercedilla', 'Chapinería', 'Chinchón', 'Ciempozuelos', 'Cobeña', 'Collado Mediano', 'Collado Villalba', 'Colmenar Viejo', 'Colmenar de Oreja', 'Colmenar del Arroyo', 'Colmenarejo', 'Corpa', 'Coslada', 'Cubas de la Sagra', 'Daganzo de Arriba', 'El Atazar', 'El Berrueco', 'El Boalo - Cerceda – Mataelpino', 'El Escorial', 'El Molar (Madrid)', 'El Vellón', 'El Álamo', 'Estremera', 'Fresnedillas de la Oliva', 'Fresno de Torote', 'Fresno de Torote - Serracines', 'Fuenlabrada', 'Fuente El Saz de Jarama', 'Fuentidueña de Tajo', 'Galapagar', 'Garganta de los Montes', 'Gargantilla del Lozoya', 'Gascones', 'Getafe', 'Griñón', 'Guadalix de la Sierra', 'Guadarrama', 'Horcajo de la Sierra', 'Hoyo de Manzanares', 'Humanes de Madrid', 'La Cabrera', 'La Hiruela', 'Las Rozas de Madrid', 'Leganés', 'Loeches', 'Los Molinos', 'Los Santos de la Humosa', 'Lozoya', 'Lozoyuela-navas-sieteiglesias', 'Madarcos', 'Majadahonda', 'Manzanares El Real', 'Meco', 'Mejorada del Campo', 'Miraflores de la Sierra', 'Montejo de la Sierra', 'Moraleja de Enmedio', 'Moralzarzal', 'Morata de Tajuña', 'Móstoles', 'Navacerrada', 'Navalafuente', 'Navalagamella', 'Navalcarnero', 'Navarredonda', 'Navas del Rey', 'Nuevo Baztán', 'Orusco de Tajuña', 'Paracuellos de Jarama', 'Parla', 'Patones', 'Pedrezuela', 'Pelayos de la Presa', 'Perales de Tajuña', 'Pezuela de las Torres', 'Pinilla del Valle', 'Pinto', 'Piñuécar-gandullas', 'Pozuelo de Alarcón', 'Pozuelo del Rey', 'Puentes Viejas', 'Quijorna', 'Rascafría', 'Redueña', 'Ribatejada', 'Rivas-vaciamadrid', 'Robledo de Chavela', 'Robregordo', 'San Agustín del Guadalix', 'San Fernando de Henares', 'San Lorenzo de El Escorial', 'San Martín de Valdeiglesias', 'San Martín de la Vega', 'San Sebastián de los Reyes', 'Santa María de la Alameda', 'Santorcaz', 'Serranillos del Valle', 'Sevilla la Nueva', 'Soto del Real', 'Talamanca de Jarama', 'Tielmes', 'Titulcia', 'Torrejón de Ardoz', 'Torrejón de Velasco', 'Torrejón de la Calzada', 'Torrelaguna', 'Torrelodones', 'Torremocha de Jarama', 'Torres de la Alameda', 'Tres Cantos', 'Valdaracete', 'Valdeavero', 'Valdelaguna', 'Valdemanco', 'Valdemaqueda', 'Valdemorillo', 'Valdemoro', 'Valdeolmos-Alalpardo', 'Valdepiélagos', 'Valdetorres de Jarama', 'Valdilecha', 'Valverde de Alcalá', 'Velilla de San Antonio', 'Venturada', 'Villa del Prado', 'Villaconejos', 'Villalbilla', 'Villamanrique de Tajo', 'Villamanta', 'Villamantilla', 'Villanueva de Perales', 'Villanueva de la Cañada', 'Villanueva del Pardillo', 'Villar del Olmo', 'Villarejo de Salvanés', 'Villaviciosa de Odón', 'Villavieja del Lozoya', 'Zarzalejo']

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
ds.isna()
#ds.columns[ds.isna().any()].tolist()
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
#        url_inmueble  rooms  bathrooms  surface  price  ...  level4Id  \
# 0             False  False      False    False  False  ...     False
# 1             False  False      False     True  False  ...     False
# 2             False  False      False    False  False  ...     False
# 3             False  False      False    False  False  ...     False
# 4             False  False      False    False  False  ...     False
# ...             ...    ...        ...      ...    ...  ...       ...
# 15330         False  False      False    False  False  ...     False
# 15331         False  False      False    False  False  ...     False
# 15332         False  False      False    False  False  ...     False
# 15333         False  False      False    False  False  ...     False
# 15334         False  False      False    False  False  ...     False
#
#        level5Id  level6Id  level7Id  level8Id  accuracy  latitude  longitude  \
# 0         False     False     False     False     False     False      False
# 1         False     False     False     False     False     False      False
# 2         False     False     False     False     False     False      False
# 3         False     False     False     False     False     False      False
# 4         False     False     False     False     False     False      False
# ...         ...       ...       ...       ...       ...       ...        ...
# 15330     False     False     False     False     False     False      False
# 15331     False     False     False     False     False     False      False
# 15332     False     False     False     False     False     False      False
# 15333     False     False     False     False     False     False      False
# 15334     False     False     False     False     False     False      False
#
#        zipCode  customZone
# 0         True        True
# 1         True        True
# 2         True        True
# 3         True        True
# 4         True        True
# ...        ...         ...
# 15330     True        True
# 15331     True        True
# 15332     True        True
# 15333     True        True
# 15334     True        True
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
ds.dropna(axis=1, how="any", inplace=True)

print(ds.isna())
# Out:
#        Unnamed: 0  id_realEstates  isNew  url_inmueble  price   date  address  \
# 0           False           False  False         False  False  False    False
# 1           False           False  False         False  False  False    False
# 2           False           False  False         False  False  False    False
# 3           False           False  False         False  False  False    False
# 4           False           False  False         False  False  False    False
# ...           ...             ...    ...           ...    ...    ...      ...
# 15330       False           False  False         False  False  False    False
# 15331       False           False  False         False  False  False    False
# 15332       False           False  False         False  False  False    False
# 15333       False           False  False         False  False  False    False
# 15334       False           False  False         False  False  False    False
#
#        country  level1  level2  ...  level2Id  level3Id  level4Id  level5Id  \
# 0        False   False   False  ...     False     False     False     False
# 1        False   False   False  ...     False     False     False     False
# 2        False   False   False  ...     False     False     False     False
# 3        False   False   False  ...     False     False     False     False
# 4        False   False   False  ...     False     False     False     False
# ...        ...     ...     ...  ...       ...       ...       ...       ...
# 15330    False   False   False  ...     False     False     False     False
# 15331    False   False   False  ...     False     False     False     False
# 15332    False   False   False  ...     False     False     False     False
# 15333    False   False   False  ...     False     False     False     False
# 15334    False   False   False  ...     False     False     False     False
#
#        level6Id  level7Id  level8Id  accuracy  latitude  longitude
# 0         False     False     False     False     False      False
# 1         False     False     False     False     False      False
# 2         False     False     False     False     False      False
# 3         False     False     False     False     False      False
# 4         False     False     False     False     False      False
# ...         ...       ...       ...       ...       ...        ...
# 15330     False     False     False     False     False      False
# 15331     False     False     False     False     False      False
# 15332     False     False     False     False     False      False
# 15333     False     False     False     False     False      False
# 15334     False     False     False     False     False      False
#
# [15335 rows x 25 columns]

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
data = ds[ds['level5'] == "Arroyomolinos (Madrid)"]

mean_price = data['price'].mean()

print(mean_price)
print(data)


#ds_group = ds.groupby("level5")
#ds_group.get_group("Arroyomolinos (Madrid)")

#df_group = ds[ds[“Product_Category”]]

#print(ds_group)



# I have selected all of the information within the dataset in relation to Arroyomolinos, Madrid, and then calculated the mean price within that column.
# Out:
# 294541.59854014596
#        Unnamed: 0  id_realEstates  isNew  \
# 453           454       153843083  False
# 607           608       153620088  False
# 613           614       153478908  False
# 707           708       153736961  False
# 852           853       153274493  False
# ...           ...             ...    ...
# 15019       15020       152767314  False
# 15089       15090       152767395  False
# 15091       15092       152767377  False
# 15094       15095       152767335  False
# 15192       15193       146831440  False
#
#                                             url_inmueble   price  \
# 453    https://www.fotocasa.es/es/comprar/vivienda/ma...  165338
# 607    https://www.fotocasa.es/es/comprar/vivienda/ma...  251646
# 613    https://www.fotocasa.es/es/comprar/vivienda/ma...  396000
# 707    https://www.fotocasa.es/es/comprar/vivienda/po...  225000
# 852    https://www.fotocasa.es/es/comprar/vivienda/ma...  373000
# ...                                                  ...     ...
# 15019  https://www.fotocasa.es/vivienda/getafe/calle-...  218000
# 15089  https://www.fotocasa.es/es/comprar/vivienda/ar...  230000
# 15091  https://www.fotocasa.es/es/comprar/vivienda/ar...  217000
# 15094  https://www.fotocasa.es/es/comprar/vivienda/ar...  227000
# 15192  https://www.fotocasa.es/es/comprar/vivienda/ma...  462000
#
#                                date                                   address  \
# 453    2019-12-28T18:58:32.9299336Z                    Arroyomolinos (Madrid)
# 607    2019-12-28T19:14:17.4310678Z                    Arroyomolinos (Madrid)
# 613    2019-12-28T19:14:17.4310678Z  Avenida Islandia, Arroyomolinos (Madrid)
# 707            2019-12-28T19:07:00Z                    Arroyomolinos (Madrid)
# 852            2019-12-28T12:30:00Z                    Arroyomolinos (Madrid)
# ...                             ...                                       ...
# 15019          2019-12-18T05:04:00Z      Almeria (De), Arroyomolinos (Madrid)
# 15089          2019-12-18T03:29:00Z      Almeria (De), Arroyomolinos (Madrid)
# 15091          2019-12-18T03:21:00Z      Almeria (De), Arroyomolinos (Madrid)
# 15094          2019-12-18T03:07:00Z      Almeria (De), Arroyomolinos (Madrid)
# 15192          2019-12-17T22:00:00Z                    Arroyomolinos (Madrid)
#
#       country  level1  level2  ... level2Id level3Id level4Id  level5Id  \
# 453    España  Madrid  Madrid  ...        0        0        0         0
# 607    España  Madrid  Madrid  ...        0        0        0         0
# 613    España  Madrid  Madrid  ...        0        0        0         0
# 707    España  Madrid  Madrid  ...        0        0        0         0
# 852    España  Madrid  Madrid  ...        0        0        0         0
# ...       ...     ...     ...  ...      ...      ...      ...       ...
# 15019  España  Madrid  Madrid  ...        0        0        0         0
# 15089  España  Madrid  Madrid  ...        0        0        0         0
# 15091  España  Madrid  Madrid  ...        0        0        0         0
# 15094  España  Madrid  Madrid  ...        0        0        0         0
# 15192  España  Madrid  Madrid  ...        0        0        0         0
#
#        level6Id  level7Id  level8Id  accuracy          latitude  \
# 453           0         0         0         0          40,27657
# 607           0         0         0         0  40,2568635154027
# 613           0         0         0         1        40,2839697
# 707           0         0         0         0        40,2779047
# 852           0         0         0         0        40,2827315
# ...         ...       ...       ...       ...               ...
# 15019         0         0         0         0       40,27849764
# 15089         0         0         0         0       40,27849764
# 15091         0         0         0         0       40,27849764
# 15094         0         0         0         0       40,27849764
# 15192         0         0         0         0         40,270392
#
#                longitude
# 453             -3,91864
# 607    -3,91214199444133
# 613           -3,9268743
# 707           -3,9136693
# 852           -3,9120264
# ...                  ...
# 15019        -3,91184112
# 15089        -3,91184112
# 15091        -3,91184112
# 15094        -3,91184112
# 15192  -3,90373610000006
#
# [137 rows x 25 columns]

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
import matplotlib.pyplot as plt

population_ds = ds['price']

plt.hist(population_ds, bins=10, color='blue', alpha=0.7)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Prices for Column Level5')
plt.grid(True)
plt.show()

data = ds[ds['level5'] == "Arroyomolinos (Madrid)"]
plt.hist(data['price'])
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 09. Are the averages of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
data_v = ds[ds['level5'] == "Valdemorillo"]
data_g = ds[ds['level5'] == "Galapagar"]

mean_price_v = data_v['price'].mean()
mean_price_g = data_g['price'].mean()

print(f"Conclusion:  The average price of Valdemorillo is {mean_price_v} and the average price of Galapagar is {mean_price_g}.  So in conclusion, the values are not the same.")
# Out:
# Conclusion:  The average price of Valdemorillo is 363860.2931034483 and the average price of Galapagar is 360063.20238095237.  So in conclusion, the values are not the same.

# %% [markdown]
# #### Exercise 10. Are the averages of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# print(ds.columns)

# data = ds[ds['level5'].isin(["Valdemorillo", "Galapagar"])]
# ds['pps'] = data['price'] / data['surface']

# avg_price_valdemorillo = ds[ds['level5'] == 'Valdemorillo']['pps'].mean()
# avg_price_galapagar = ds[ds['level5'] == 'Galapagar']['pps'].mean()

# print(f"The average price for Valdemorillo is {avg_price_valdemorillo} and for Galapagar is {avg_price_galapagar}")

surface_data = 'surface'
if len(ds) == len(surface_data):
    # Add 'surface' column to your dataset
    ds['surface'] = surface_data['surface']  # Replace 'surface_column_name' with the actual column name in your surface data
else:
    print("Lengths of datasets do not match. Unable to add 'surface' column.")
# Selecting data for Valdemorillo and Galapagar
data = ds[ds['level5'].isin(["Valdemorillo", "Galapagar"])]

# Calculate price per square meter (pps)
data['pps'] = data['price'], data['level5']  # Here is where the error occurs

# Calculate average price per square meter for Valdemorillo
avg_price_valdemorillo = data[data['level5'] == 'Valdemorillo']['pps'].mean()

# Calculate average price per square meter for Galapagar
avg_price_galapagar = data[data['level5'] == 'Galapagar']['pps'].mean()

# Print the average prices per square meter for both areas
print(f"The average price per square meter for Valdemorillo is {avg_price_valdemorillo} and for Galapagar is {avg_price_galapagar}")
# Out:
# Lengths of datasets do not match. Unable to add 'surface' column.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[143], line 21
#      18 data = ds[ds['level5'].isin(["Valdemorillo", "Galapagar"])]
#      20 # Calculate price per square meter (pps)
# ---> 21 data['pps'] = data['price'], data['level5']  # Here is where the error occurs
#      23 # Calculate average price per square meter for Valdemorillo
#      24 avg_price_valdemorillo = data[data['level5'] == 'Valdemorillo']['pps'].mean()
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4296     self._setitem_array([key], value)
#    4297 else:
#    4298     # set column
# -> 4299     self._set_item(key, value)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:4512, in DataFrame._set_item(self, key, value)
#    4502 def _set_item(self, key, value) -> None:
#    4503     """
#    4504     Add series to DataFrame in specified column.
#    4505
#    (...)
#    4510     ensure homogeneity.
#    4511     """
# -> 4512     value, refs = self._sanitize_column(value)
#    4514     if (
#    4515         key in self.columns
#    4516         and value.ndim == 1
#    4517         and not isinstance(value.dtype, ExtensionDtype)
#    4518     ):
#    4519         # broadcast across multiple columns if necessary
#    4520         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:5253, in DataFrame._sanitize_column(self, value)
#    5250     return _reindex_for_setitem(value, self.index)
#    5252 if is_list_like(value):
# -> 5253     com.require_length_match(value, self.index)
#    5254 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5255 if (
#    5256     isinstance(value, Index)
#    5257     and value.dtype == "object"
#    (...)
#    5260     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5261     # this deprecation
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (2) does not match length of index (142)

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
import matplotlib as plt

price = ds['price']
surface = ds['surface']


plt.scatter(x='surface' , y='price', color='blue' , alpha=0.7)

plt.xlabel('Surface')
plt.ylabel('Price')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'surface'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 4
#       1 import matplotlib as plt
#       3 price = ds['price']
# ----> 4 surface = ds['surface']
#       7 plt.scatter(x='surface' , y='price', color='blue' , alpha=0.7)
#       9 plt.xlabel('Surface')
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'surface'

# %% [markdown]
# After looking at this scatterplot, you can quite plainly see that as the 'surface' or metros cuadrados increases, the value ('price') of the house increases.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
num_agencies = ds['id_realEstates'].nunique()

print("Number of Real Estate Agencies:", num_agencies)
# Out:
# Number of Real Estate Agencies: 14217

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
population = ds['level5'].__len__()
number_of_houses = ds['level5'].count()


print(population, number_of_houses)
# Out:
# 15335 15335

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
south_belt = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

print(south_belt)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                             url_inmueble   price  \
# 1      https://www.fotocasa.es/es/comprar/vivienda/ma...   89000
# 3      https://www.fotocasa.es/es/comprar/vivienda/ma...   89000
# 85     https://www.fotocasa.es/es/comprar/vivienda/le...  107000
# 94     https://www.fotocasa.es/es/comprar/vivienda/le...  320000
# 109    https://www.fotocasa.es/es/comprar/vivienda/ma...  425000
# ...                                                  ...     ...
# 15275  https://www.fotocasa.es/es/comprar/vivienda/al...  138000
# 15291  https://www.fotocasa.es/es/comprar/vivienda/al...  279000
# 15305  https://www.fotocasa.es/es/comprar/vivienda/ma...  170000
# 15322  https://www.fotocasa.es/es/comprar/vivienda/ma...  112000
# 15325  https://www.fotocasa.es/es/comprar/vivienda/ma...  215000
#
#                                date  \
# 1      2019-12-28T18:27:15.9975027Z
# 3      2019-12-28T18:27:15.9975027Z
# 85      2019-12-28T18:30:53.960102Z
# 94      2019-12-28T18:30:53.960102Z
# 109    2019-12-28T18:32:32.5337942Z
# ...                             ...
# 15275          2019-12-17T19:02:00Z
# 15291          2019-12-17T18:57:00Z
# 15305          2019-12-17T18:43:00Z
# 15322          2019-12-17T18:25:00Z
# 15325          2019-12-17T18:24:00Z
#
#                                                  address country  level1  \
# 1                       Calle Polvoranca, 6, Fuenlabrada  España  Madrid
# 3                         Barrio San Andres, Fuenlabrada  España  Madrid
# 85                   Avenida Carabancheles, 18, Alcorcón  España  Madrid
# 94                            Avenida Los Pinos, Leganés  España  Madrid
# 109                                             Alcorcón  España  Madrid
# ...                                                  ...     ...     ...
# 15275  Urbanización Urbanización Parque Miraflores, 5...  España  Madrid
# 15291                                            Leganés  España  Madrid
# 15305                                        Fuenlabrada  España  Madrid
# 15322            Calle Dr. Miguel de Aguado, Fuenlabrada  España  Madrid
# 15325           Calle de Luis Sauquillo, 77, Fuenlabrada  España  Madrid
#
#        level2  ... level2Id level3Id level4Id  level5Id  level6Id  level7Id  \
# 1      Madrid  ...        0        0        0         0         0         0
# 3      Madrid  ...        0        0        0         0         0         0
# 85     Madrid  ...        0        0        0         0         0         0
# 94     Madrid  ...        0        0        0         0         0         0
# 109    Madrid  ...        0        0        0         0         0         0
# ...       ...  ...      ...      ...      ...       ...       ...       ...
# 15275  Madrid  ...        0        0        0         0         0         0
# 15291  Madrid  ...        0        0        0         0         0         0
# 15305  Madrid  ...        0        0        0         0         0         0
# 15322  Madrid  ...        0        0        0         0         0         0
# 15325  Madrid  ...        0        0        0         0         0         0
#
#        level8Id  accuracy          latitude          longitude
# 1             0         1          40,28674           -3,79351
# 3             0         0  40,2853785786438  -3,79508142135624
# 85            0         1          40,35059           -3,82693
# 94            0         0          40,31933           -3,77574
# 109           0         0        40,3313411         -3,8313868
# ...         ...       ...               ...                ...
# 15275         0         1          40,31381           -3,83733
# 15291         0         0        40,3259051           -3,76318
# 15305         0         0        40,2882193         -3,8098617
# 15322         0         0          40,28282           -3,78892
# 15325         0         1          40,28062           -3,79869
#
# [907 rows x 25 columns]

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
import matplotlib.pyplot as plt

south_belt = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

plt.bar(x= , y=south_belt).median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 5
#       1 import matplotlib.pyplot as plt
#       3 south_belt = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]
# ----> 5 plt.bar(south_belt).median()
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
south_belt = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
south_belt = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
south_belt = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
south_belt = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
south_belt = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 6
#       1 from ipyleaflet import Map, basemaps
#       3 # Map centred on (60 degrees latitude et -2.2 degrees longitude)
#       4 # Latitude, longitude
#       5 map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20,
# ----> 6     basemap=basemaps.Stamen.Terrain)
#       7 map
#
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:46, in Bunch.__getattr__(self, key)
#      44     return self.__getitem__(key)
#      45 except KeyError as err:
# ---> 46     raise AttributeError(key) from err
#
# AttributeError: Stamen

# %%
## HERE: plot the coordinates of the estates

## PUT HERE YOUR CODE:
